# %%
import pandas as pd

# %%
screened_path = ('./energy.firms.crsp.screened (1).xlsx')
full_list_path = ('./energy.firms.returns.static.xlsx')

# %%
screened_pd = pd.ExcelFile(screened_path)

# %%
full_list_pd = pd.ExcelFile(full_list_path)

# %%
print(screened_pd.sheet_names)
print(full_list_pd.sheet_names)
# Out:
# ['Sheet1']
# ['__FDSCACHE__', 'energy.firms.returns.static']
